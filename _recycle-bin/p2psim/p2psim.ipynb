# %%
# %matplotlib widget

import src.p2psim as sim

fig, ani = sim.run("Propagación ejemplo", interval=2000, origin=0, total_nodes=8, async_mode=True, simulate_delay=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
