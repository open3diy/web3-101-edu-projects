# %% [markdown]
# ℹ️ Para entender Merkle DAG, aquí tienes estas explicaciones con las que puedes iniciar:
#
# * [Jugando con árbol Merkle](../_misc/merkle_playground.ipynb).
# * [Jugando con DAG](../_misc/dag_playground.ipynb).

# %% [markdown]
# 🌿 Merkle DAG de IPFS:
#
# Todo árbol de Merkle, forma un grafo acíclico dirigido que va desde la raíz a los nodos hoja, IPFS enfatiza que es DAG para resaltar que permite nodos compartidos (varios padres).
#
# Un árbol de Merkle es un caso específico de grafo acíclico dirigido (DAG), con una raíz y nodos intermedios.
#
# Todo árbol de Merkle es un DAG, pero no todo DAG es un árbol de Merkle.
#
# Como vemos normalmente representado un Merkle DAG de IPFS:

# %%
# Probar ejemplo
from src.merkle_dag_playground import *

G.clear()

G.add_edges_from([
    ("Root", "Node AB"),
    ("Root", "Node CD"),

    ("Node AB", "Block A"),
    ("Node AB", "Block B"),
 
    ("Node CD", "Block C"),
    ("Node CD", "Block D"),
])

IPFS_draw()
